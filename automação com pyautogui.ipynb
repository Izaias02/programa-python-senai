# %% [markdown]
# Exercício 09 – Crie um código para abrir o Bloco de notas e digite a frase
# Hello, World!

# %%
import pyautogui                # gerar a automação
import time                     # gerar o tempo de execução
import os                       # gerenciar os arquivos no sistema operacional

# ------------------------------------------------------------------------------

# abrir o bloco de notas

pyautogui.press('win')

time.sleep(0.5)
pyautogui.write('Bloco de notas')
pyautogui.press('enter')

time.sleep(1)

texto = 'Hello,baby!'
pyautogui.write(texto)

time.sleep(1)
pyautogui.hotkey('ctrl','s')
time.sleep(1)
pyautogui.write('teste.txt')
pyautogui.press('enter')

# %%
# !pip install pyautogui
# Out:
# ^C
# ...
#      ---------------------------------------- 61.2/61.2 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
pip install pyautogui

import pyautogui

#Movimentar o mouse nas coordenadas (x, y)
pyautogui.moveTo(500, 500,10)
  # Descobrir a posição de um elemento
pyautogui.position()

# Movimentar para uma posição especifica

pyautogui.move(1707,729,5)
 +55 11 97774-0658: # Importar a biblioteca time
import time

# Aguardar alguns instantes antes de iniciar a digitação

time.sleep(5)

# Digite um texto


pyautogui.write('Hello, baby!')
 import pyautogui

# Obtenha as coordenadas atuais do mouse

x, y = pyautogui.position()

print(f'Posição atual do mouse: x = {x}, y = {y}')
 import time

# Clicar no botão inicial e digitar Bloco de notas e clicar e po fim digitar

pyautogui.click(18, 1067) # Clicar no botão inicial atraves das coordenadas 

pyautogui.write('Bloco de notas') # Digitar Bloco de notas

pyautogui.press('enter') # Clicar

time.sleep(1) #esperar um determinado tempo para digitar.
pyautogui.write('Salveeeeee!!!') # Digitar
 # Realizar um clique duplo nas coordenadas(x, y)

pyautogui.doubleClick(1153,8)
import time
pyautogui.click(15, 1076)#---------------------------------------- Clicar no botão iniciar
time.sleep(1)#---------------------------------------------------- Aguardar 1 segundo  
pyautogui.write('Google')#---------------------------------------- Digitar Google

pyautogui.press('enter')#----------------------------------------- Pressionar o ENTER

time.sleep(2)#----------------------------------------------------- Aguardar 2 segundos
pyautogui.write('https://sp.senai.br/unidade/suicobrasileira/')#--- Pesquisar através do Link da escola
pyautogui.press('enter')
Rua Guairac, 154 - Embu das Artes/Sp
time.sleep(2)#----------------------------------------------------- Aguarda 2 segundos
pyautogui.click(1282,510)#----------------------------------------- Clicar atrvés das coordenadas 

time.sleep(2)#----------------------------------------------------- Esperar 2 segundos
pyautogui.click(448, 319)#----------------------------------------- Clicar atrvés das cRua Guairac, 154 - Embu das Artes/Spoordenadas 

time.sleep(1)#----------------------------------------------------- Aguardar 1 segundo
pyautogui.write('FMEA')#------------------------------------------- Digitar FMEA
time.sleep(1)#----------------------------------------------------- Aguardar 1 segundo
pyautogui.press('enter')#------------------------------------------ Pressionar o ENTER
time.sleep(1)#----------------------------------------------------- Aguardar 1 segundo  
pyautogui.click(849,  728)#---------------------------------------- Clicar atrvés das coordenadas

# %% [markdown]
# exercico extra 01

# %% [markdown]
# gerar um codigo para localizar a posição de uma imagem em uma pagina web

# %%
import pyautogui        # gerar a automação das tarefas
import time             # gerenciar o tempo de execução

#  pressionar as teclas  WIN + R
time.sleep(0.5)
pyautogui.hotkey('win','r')

pyautogui.typewrite('https://forms.gle/1rfKi5BEicT6JgZz9 \n')

# tirar uma soneca

time.sleep(2)

a, b = pyautogui.locateCenterOnScreen('img.png')

time.sleep(1)
pyautogui.click(x = a,y = b + 20)

time.sleep(1)
pyautogui.write('izaias')

time.sleep(1)
pyautogui.press('tab')
pyautogui.write('salgado')

time.sleep(1)
pyautogui.press('tab')
pyautogui.write('santos')

time.sleep(1)
pyautogui.press('tab')
pyautogui.write('991954632')

time.sleep(1)
pyautogui.press('tab')
pyautogui.write('rua caetes numero 37')

time.sleep(1)
pyautogui.press('tab')
pyautogui.write('izaiasantos20302@gmail.com')

time.sleep(1)
pyautogui.press('tab')
pyautogui.write('izaiasantos20302@gmail.com')
